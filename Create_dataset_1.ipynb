# %%
# !pip install emoji
# Out:
# Collecting emoji
#   Downloading emoji-2.8.0-py2.py3-none-any.whl (358 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.9/358.9 kB 5.9 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.8.0

# %%
import pandas as pd
import numpy as np
import os
import glob
from tqdm import tqdm
from geopy.geocoders import Photon
from geopy.exc import GeocoderTimedOut, GeocoderUnavailable
from transformers import GPTNeoForCausalLM, GPT2Tokenizer
import torch
import emoji
import re
import cv2
from google.colab.patches import cv2_imshow
from torchvision.io import read_image, ImageReadMode

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
working_dir = '/content/drive/MyDrive/Datasets' #upperdirectorythat coontains data + images
data_dir = os.path.join(working_dir, 'Data', '') # directory that contains data
images_dir = os.path.join(working_dir, 'Images', '') # directory that contains images

# %%
print(data_dir)
# Out:
# /content/drive/MyDrive/Datasets/Data/

# %%
df_concat = pd.concat([pd.read_csv(f) for f in glob.glob(data_dir + '/*.csv') ], ignore_index=True)
df_concat = df_concat.loc[:, ~df_concat.columns.str.contains('^Unnamed')]

df_concat.dropna(subset=['post_url'], inplace=True) # drop rows that we don't have images for

# drop rows with corapt data
df_concat.drop(df_concat[df_concat['followers'] < 0].index, inplace = True)
df_concat.drop(df_concat[df_concat['followees'] < 0].index, inplace = True)
df_concat.drop(df_concat[df_concat['likes'] < 0].index, inplace = True)
df_concat.drop(df_concat[df_concat['comments'] < 0].index, inplace = True)

# conver business_category to strinng
df_concat['business_category'] = df_concat['business_category'].astype(str)

# conver caption to strinng
df_concat['caption'] = df_concat['caption'].astype(str)

# conver location to strinng
df_concat['location'] = df_concat['location'].astype(str)

df_concat = df_concat.reset_index(drop=True) # reset index
df_concat
# Out:
#           username  followers  followees  is_verified  is_business  \
# 0        fehertwit     104499         28         True         True
# 1        fehertwit     104499         28         True         True
# 2        fehertwit     104499         28         True         True
# 3        fehertwit     104499         28         True         True
# 4        fehertwit     104499         28         True         True
# ...            ...        ...        ...          ...          ...
# 2666  annehathaway   30980252        101         True        False
# 2667  annehathaway   30980252        101         True        False
# 2668  annehathaway   30980252        101         True        False
# 2669  annehathaway   30980252        101         True        False
# 2670  annehathaway   30980252        101         True        False
#
#      business_category  number_of_posts  \
# 0       Content & Apps              626
# 1       Content & Apps              626
# 2       Content & Apps              626
# 3       Content & Apps              626
# 4       Content & Apps              626
# ...                ...              ...
# 2666               nan              738
# 2667               nan              738
# 2668               nan              738
# 2669               nan              738
# 2670               nan              738
#
#                                                post_url  \
# 0     https://scontent-hou1-1.cdninstagram.com/v/t51...
# 1     https://scontent-hou1-1.cdninstagram.com/v/t51...
# 2     https://scontent-hou1-1.cdninstagram.com/v/t51...
# 3     https://scontent-hou1-1.cdninstagram.com/v/t51...
# 4     https://scontent-hou1-1.cdninstagram.com/v/t51...
# ...                                                 ...
# 2666  https://scontent-lga3-1.cdninstagram.com/v/t51...
# 2667  https://scontent-lga3-1.cdninstagram.com/v/t51...
# 2668  https://scontent-lga3-2.cdninstagram.com/v/t51...
# 2669  https://scontent-lga3-2.cdninstagram.com/v/t51...
# 2670  https://scontent-lga3-2.cdninstagram.com/v/t51...
#
#                                                 caption  \
# 0     At least I don’t have to wear this in Stamford...
# 1     Silencing all other competitors today at Augus...
# 2     Happy 50th birthday to this guy! Nobody rocks ...
# 3     61 years young today... Happy Birthday to the ...
# 4     “See David, the key to success in majors is ga...
# ...                                                 ...
# 2666  Mamazon.\nPhotos: @hairbyadir \n@kateleemakeup...
# 2667  @voguehongkong and I will just leave these her...
# 2668  Grazie @donatella_versace and @versace for the...
# 2669  ✨ Very lucky I was able to celebrate @bulgari'...
# 2670  Miracles happen… Happy 20th Birthday to #thepr...
#
#                                hashtags      likes  comments location  \
# 0                                    []    12225.0     218.0      nan
# 1                ['themasters', 'golf']     6919.0      61.0      nan
# 2                                    []     4125.0      57.0      nan
# 3                                    []     3529.0     152.0      nan
# 4                                    []     3520.0      22.0      nan
# ...                                 ...        ...       ...      ...
# 2666                                 []  3225787.0   20034.0      nan
# 2667          ['creativecastingagency']  3096398.0   12795.0      nan
# 2668                                 []  3034865.0    5119.0      nan
# 2669  ['bulgari', 'bulgarihighjewelry']  3021947.0    7064.0      nan
# 2670             ['theprincessdiaries']  2660441.0   18404.0      nan
#
#                  date_utc      img_type
# 0     2021-07-16 15:59:55    GraphImage
# 1     2018-04-08 22:47:38    GraphImage
# 2     2020-06-16 13:44:42  GraphSidecar
# 3     2019-08-13 14:46:32    GraphImage
# 4     2019-05-18 20:32:12  GraphSidecar
# ...                   ...           ...
# 2666  2019-10-11 19:44:26  GraphSidecar
# 2667  2022-10-29 22:02:03  GraphSidecar
# 2668  2023-03-11 00:26:25  GraphSidecar
# 2669  2023-05-20 17:01:10  GraphSidecar
# 2670  2021-07-29 14:26:21  GraphSidecar
#
# [2671 rows x 15 columns]

# %% [markdown]
# # Username encoding

# %%
def usernanme_encoding(usrn):
  return float(list(np.unique(df_concat['username'])).index(usrn) + 1)

# %%
usernanme_encoding('_katiegeorge_')
# Out:
# 1.0

# %% [markdown]
# # Verification status encoding

# %%
print(f"Verification Status: {list(np.unique(df_concat['is_verified']))}")
print(f' False --> {float(False)}, True --> {float(True)}')
# Out:
# Verification Status: [False, True]
#  False --> 0.0, True --> 1.0

# %% [markdown]
# # Business status encoding

# %%
print(f"Business Status: {list(np.unique(df_concat['is_business']))}")
print(f' False --> {float(False)}, True --> {float(True)}')
# Out:
# Business Status: [False, True]
#  False --> 0.0, True --> 1.0

# %% [markdown]
# # Business category encoding

# %%
def business_category_encoding(label):
  list_tmp = list(np.unique(df_concat['business_category']))
  list_tmp.remove('nan')
  list_tmp.insert(0, 'nan')
  list_tmp.remove('None')
  list_tmp.insert(1, 'None')
  return float(list_tmp.index(label))

# %%
for elem in list(np.unique(df_concat['business_category'])):
  print(f'{elem} --> {business_category_encoding(elem)}')
# Out:
# Content & Apps --> 2.0
# Creators & Celebrities --> 3.0
# Entities --> 4.0
# Government Agencies --> 5.0
# Grocery & Convenience Stores --> 6.0
# Home Services --> 7.0
# Local Events --> 8.0
# None --> 1.0
# Personal Goods & General Merchandise Stores --> 9.0
# Professional Services --> 10.0
# Publishers --> 11.0
# nan --> 0.0

# %% [markdown]
11, 119, 17, 16, 22, 91, 9, 8, 3, 62, 39, 103, 55, 20, 11, 5, 22, 3, 13, 41, 18, 99, 25, 19, 27, 69, 17, 33, 113, 9, 63, 3, 28, 24, 120, 33, 119, 67, 43, 137, 171, 8, 8, 30, 11, 29, 28, 28, 17, 5, 6, 13, 13, 49, 44, 109, 25, 28, 26, 18, 22, 6, 55, 16, 178, 53, 8, 79, 27, 46, 7, 4, 267, 7, 3, 75, 138, 48, 33, 15, 47, 24, 111, 4, 18, 24, 380, 55, 25, 5, 103, 7, 124, 149, 23, 31, 6, 5, 19, 156, 36, 3, 15, 3, 4, 14, 63, 128, 4, 179, 9,  ...
# MIN: 1
# MEAN: 30.878515625
# MAX: 435
# MEDIAN: 15.0

# %%
def caption_tokenizer(tokenizer, caption):
  input_ids = tokenizer(caption,max_length=50, padding='max_length', truncation=True).input_ids
  return input_ids

# %%
def extract_emojis(s):
    return ''.join(c for c in s if c in emoji.distinct_emoji_list(s))

# %%
def caption_encoding(tokenizer, caption):
  return caption_tokenizer(tokenizer, caption), len(extract_emojis(caption))

# %%
tokenizer = GPT2Tokenizer.from_pretrained("EleutherAI/gpt-neo-2.7B")
tokenizer.pad_token = tokenizer.eos_token

for caption in list(np.unique(df_concat['caption']))[:5]:
  # input_ids = tokenizer(prompt, return_tensors="pt").input_ids
  print(f'CAPTION: {caption}')
  cap, emoj = caption_encoding(tokenizer, caption)
  print(f'TOKENIZED CAPTION: {cap} & LENGTH: {len(caption_tokenizer(tokenizer,caption))} \n')
  print(f'NUMBER OF EMOJIS: {emoj}')
# Out:
# tokenizer_config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# CAPTION: "A world in which elves exist and magic works. "
#
# Everytime we visited that area it felt like being in some kind of fairytale lands with absolutely noone around , I really wanted to represented it like that through the photos .
# We did 5x visits to this area but everytime we just didn't get the right conditions either it started  raining out of nowhere or just massive fog with no visibility at all which seemed to last forever. There was just this one moment which only lasted a few minutes where the magic light came in and we finally got what we wanted .
#
# I guess the story here is if you want something you have to work hard , there are never any shortcuts ever .
# #iceland .
# @beyondthelands | @simona_br_photography
# __________________
#
# www.beyondthelands.com
# TOKENIZED CAPTION: [1, 32, 995, 287, 543, 31959, 2152, 290, 5536, 2499, 13, 366, 198, 198, 6109, 2435, 356, 8672, 326, 1989, 340, 2936, 588, 852, 287, 617, 1611, 286, 3148, 20760, 1000, 8604, 351, 5543, 645, 505, 1088, 837, 314, 1107, 2227, 284, 7997, 340, 588, 326, 832, 262, 5205, 764] & LENGTH: 50
#
# NUMBER OF EMOJIS: 0
# CAPTION: "Because we are all both soft whilst also being incredibly strong. One side is not weaker, less valid or less worthy. Both exist together perfectly."
# -
# Beautiful words, beautiful body, beautiful soul - @_nelly_london 💙
# -
# @Gymsharkwomen
# #Gymshark
# TOKENIZED CAPTION: [1, 8128, 356, 389, 477, 1111, 2705, 14590, 635, 852, 8131, 1913, 13, 1881, 1735, 318, 407, 17642, 11, 1342, 4938, 393, 1342, 12733, 13, 5747, 2152, 1978, 7138, 526, 198, 12, 198, 38413, 4135, 2456, 11, 4950, 1767, 11, 4950, 5848, 532, 2488, 62, 77, 6148, 62, 75, 3391] & LENGTH: 50
#
# NUMBER OF EMOJIS: 1
# CAPTION: "Beyond The Lands" Here is my last post for 2018 , want to thank everyone for the support and kindness this year , truly appreciate that! Looking forward to experience  more adventures and discovering new places on the other side . Much love and see you in 2019 !
# #iceland .
# @beyondthelands | @simona_br_photography
# __________________
#
# www.beyondthelands.com
# TOKENIZED CAPTION: [1, 24102, 383, 24182, 1, 3423, 318, 616, 938, 1281, 329, 2864, 837, 765, 284, 5875, 2506, 329, 262, 1104, 290, 23887, 428, 614, 837, 4988, 9144, 326, 0, 15616, 2651, 284, 1998, 220, 517, 17545, 290, 21611, 649, 4113, 319, 262, 584, 1735, 764, 13111, 1842, 290, 766, 345] & LENGTH: 50
#
# NUMBER OF EMOJIS: 0
# CAPTION: "Carrie holds such a special place in the hearts of everyone at Lucasfilm it is difficult to think of a world without her. She was Princess Leia to the world but a very special friend to all of us. She had an indomitable spirit, incredible wit and a loving heart. Carrie also defined the female hero of our age over a generation ago. Her groundbreaking role as Princess Leia served as an inspiration of power and confidence for young girls everywhere. We will miss her dearly." -Kathleen Kennedy
# TOKENIZED CAPTION: [1, 9914, 5034, 6622, 884, 257, 2041, 1295, 287, 262, 11954, 286, 2506, 379, 15257, 26240, 340, 318, 2408, 284, 892, 286, 257, 995, 1231, 607, 13, 1375, 373, 8449, 41212, 284, 262, 995, 475, 257, 845, 2041, 1545, 284, 477, 286, 514, 13, 1375, 550, 281, 773, 296, 4674] & LENGTH: 50
#
# NUMBER OF EMOJIS: 0
# CAPTION: "Eye Galaxy".
# What makes an image realistic, and why?
#
# Macro photos of the iris have always fascinated me. A micro galaxy full of mysterious textures looming into this eye exam question in what makes an image realistic vs digital vs illustrative?
#
# This micro world exists, but most have never seen it, hence seemingly unreal. I might go into the atom level but how am I to know what is real when I have never seen it? Maybe it all looks like neon cyberpunk cartoons in reality.
#
# What makes an image more realistic? What cues, hints, distractions, assumptions, imperfections, triggers, perceptions, etc.
#
# Why does it even matter?
#
# #aiart #aigenerating #ai #aidesign #aifuture #aicreators #aieconomy #aiartcommunity #promptable #openai #dalle2experiment  #AIExperimenting #dallebeta #dalle2 #whatisandwhy #iris #eye #definitions  #AIrealism #eyeexam #newstyles #eyegalaxy #irisgalaxy
# TOKENIZED CAPTION: [1, 24876, 9252, 1911, 198, 2061, 1838, 281, 2939, 12653, 11, 290, 1521, 30, 198, 198, 14155, 305, 5205, 286, 262, 4173, 271, 423, 1464, 30103, 502, 13, 317, 4580, 16161, 1336, 286, 11428, 20028, 28236, 656, 428, 4151, 2814, 1808, 287, 644, 1838, 281, 2939, 12653, 3691, 4875, 3691] & LENGTH: 50
#
# NUMBER OF EMOJIS: 0

# %% [markdown]
# # Hastags encoding

# %%
def clean_string(input_string):
    # Replace multiple spaces with a single space
    input_string = re.sub(r'\s+', ' ', input_string)

    # Remove everything except alphanumeric characters, underscores, and spaces
    return re.sub(r'[^\w\s]', '', input_string)

def hastags_count(has_list):
  has_list = clean_string(has_list)
  has_list = has_list.split(' ')
  if has_list == [''] : return 0.0
  else: return float(len(has_list))

# %%
for i, has_list in enumerate(list(np.unique(df_concat['hashtags']))[564:567],1):
  print(f'Post #{i} --> Hastag List: {has_list} & Hastag Count: {hastags_count(has_list)}')
# Out:
# Post #1 --> Hastag List: ['synchronic'] & Hastag Count: 1.0
# Post #2 --> Hastag List: ['synystergates', 'thedarknight', 'schecterguitars', 'synystergatesschool', 'synner', 'jointhesyndicate'] & Hastag Count: 6.0
# Post #3 --> Hastag List: ['tacotuesday'] & Hastag Count: 1.0

# %% [markdown]
# # Location encoding

# %%
def get_coordinates(address):
    if address == 'nan':
        return 0.0, 0.0

    geolocator = Photon(user_agent="measurements")

    try:
        location = geolocator.geocode(address)
        if location:
            return location.latitude, location.longitude
        else:
            return 0.0, 0.0
    except (GeocoderTimedOut, GeocoderUnavailable):
        return 0.0, 0.0

# %%
dict_addresses = {}
for addr in tqdm(list(np.unique(df_concat['location']))):
  dict_addresses[addr] = get_coordinates(addr)
# Out:
#  86%|████████▌ | 318/371 [03:58<00:38,  1.37it/s]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)")': /api?q=The+Oppenheim+Group&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)")': /api?q=The+Oppenheim+Group&limit=1
#  86%|████████▌ | 319/371 [04:03<01:39,  1.91s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)")': /api?q=The+Queen+of+The+Closet&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)")': /api?q=The+Queen+of+The+Closet&limit=1
#  86%|████████▋ | 320/371 [04:07<02:21,  2.77s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='photon.komoot.io', port=443): Read timed out. (read timeout=1)")': /api?q=The+Ritz-Carlton%2C+Bachelor+Gulch&limit=1
# 100%|██████████| 371/371 [04:47<00:00,  1.29it/s]

# %%
dict_addresses
# Out:
# {'16th Hole at the Phoenix Open': (0.0, 0.0),
#  'A.F.A. Predio Ezeiza': (-34.6859177, -58.4581601),
#  'AREA15': (-13.96101625, 33.76950792327203),
#  'Abu Dhabi Golf Club': (24.42021485, 54.52675457764596),
#  'Abu Dhabi, United Arab Emirates': (24.4538352, 54.3774014),
#  'Agios Prokopios, Naxos': (37.0750385, 25.3513495),
#  'Albert Park Circuit-Melbourne': (-37.84029685, 144.9587767846889),
#  'Alphaland': (16.4329569, 120.6515014),
#  'Altrincham': (53.3839662, -2.3525463),
#  'American Airlines Center': (32.8339093, -97.0642477),
#  'Amex Stadium': (50.8615535, -0.08487128929500862),
#  'Amman, Jordan': (31.9515694, 35.9239625),
#  'Amsterdam, Netherlands': (52.3730796, 4.8924534),
#  'Anfield Stadium Liverpool Football Club': (0.0, 0.0),
#  'Argentina': (-34.9964963, -64.9672817),
#  'Around Europe': (49.5565509, 18.8349493),
#  'ArtScience Museum': (42.860550950000004, -73.9320504042457),
#  'Aschaffenburg, Germany': (49.9740542, 9.1493636),
#  'Aspen, Colorado': (39.1911128, -106.82356),
#  'Lisbon, Portugal': (38.7077507, -9.1365919),
#  'London': (51.5074456, -0.1277653),
#  'London Stadium': (51.53862065, -0.016623759002470637),
#  'London, United Kindom': (54.7023545, -3.2765753),
#  'London, United Kingdom': (51.5074456, -0.1277653),
#  'London, Unιted Kingdom': (54.7023545, -3.2765753),
#  'Los Angeles Country Club': (34.027432250000004, -118.41547065829293),
#  'Los Angeles, California': (34.0536909, -118.242766),
#  'Louis Vuitton Foundation': (45.1199244, 4.9507189993511584),
#  'Love Town.!!!!': (44.760082499999996, -84.42820218825904),
#  'Lusail Stadium': (25.42093945, 51.49053570250075),
#  'MGM Music Hall at Fenway': (42.3466978, -71.09549531328166),
#  'Madison Square Garden': (43.1323413, -89.286783),
#  'Madrid, Spain': (40.4167047, -3.7035825),
#  'Maldives Islands': (4.6042214999999995, 73.58052810117442),
#  'Malta': (35.8885993, 14.4476911),
#  'Malta, Valletta': (35.8989818, 14.5136759),
#  'Manchester Utd Football Ground': (53.4622575, -2.2907315),
#  'Manchester, United Kingdom': (53.4794892, -2.2451148),
#  'Manhattan, New York': (40.7814865, -73.95905442771002),
#  'Marina Bay Street Circuit': (1.2948393, 103.8627335),
#  'Marquee': (-46.366775, 169.268061),
#  'Massachusetts Institute of Technology (MIT)': (42.3582529,
#   -71.0966272383055),
#  'Maui, Hawaii': (20.7580586, -156.3105232),
#  'Melbourne Cricket Ground (MCG)': (-37.8306934, 144.9421179773375),
#  'Metropolitan Museum of Art': (48.8660977, 2.3554138),
#  'Mexico City, Mexico': (19.4326296, -99.1331785),
#  'Miami, Florida': (25.7741728, -80.19362),
#  'Milan, Italy': (45.4641943, 9.1896346),
#  'Monaco': (43.7311424, 7.4197576),
#  'Monaco Grand Prix Circuit': (20.7540217, -103.3944219),
#  'Mongolia': (46.8250388, 103.8499736),
#  'Monte-Carlo, Monaco': (43.7402961, 7.426559),
#  'Monza, Italy': (45.5834418, 9.2735257),
#  'Morecambe': (54.0721085, -2.8650938),
#  'Morecambe Bay': (54.07519255, -2.851032374597738),
#  'Moscow, Russia': (55.7505412, 37.6174782),
#  'Mtv Ema Awards': (25.184724250000002, 55.34285475604389),
#  'Muchas Gracias': (45.65883335, -122.5900020562512),
#  'Mumbai, Maharashtra': (19.08157715, 72.88662753964906),
#  'Mysore, Karnataka': (12.3157394, 76.6451158),
#  'Mòleson , Gruyeres, Switzerland': (46.5642031, 7.0371126),
#  'Nagarhole Tiger Reserve.': (12.05993125, 76.15414665375948),
#  'Nashville, Tennessee': (36.1622767, -86.7742984),
#  'NeverLand': (34.7458, -120.08822187412649),
#  'New Orleans, Louisiana': (29.9759983, -90.0782127),
#  'New York City': (40.7127281, -74.0060152),
#  'New York City Ballet': (43.1698328, -78.6921293),
#  'New York City, N.Y.': (40.7127281, -74.0060152),
#  'New York, New York': (40.7127281, -74.0060152),
#  'Newport RI Police Department': (41.4930185, -71.31098336658876),
#  'Nickelodeon Studios': (0.0, 0.0),
#  'No.15 by GuestHouse, Bath': (51.38057185, -2.375937700000002),
#  'Oak Hill Country Club': (42.6305103, -83.1174486),
#  'Oeschinensee': (46.4984951, 7.726842944419969),
#  'Ohio': (40.2253569, -82.6881395),
#  'Old Trafford': (53.46310955, -2.2913864850545362),
#  'Old Trafford Stadium, Manchester': (53.46310955, -2.2913864850545362),
#  'Olympiastadion Helsinki': (60.184999250000004, 24.927380300847325),
#  'Osaka, Japan 大阪': (34.3595067, 135.2398397),
#  'Ottawa, Ontario, Canada': (45.4208777, -75.6901106),
#  'Palms Casino Resort': (-25.8167482, 25.6356441),
#  'Paris': (48.8588897, 2.3200410217200766),
#  'Paris, France': (48.8588897, 2.3200410217200766),
#  'Patagonia Argentina': (-44.99006975, -70.67343144015169),
#  'Philadelphia, Pennsylvania': (39.9527237, -75.1635262),
#  'Phuket, Thailand': (7.8847901, 98.3891503),
#  'Pinewood Atlanta Studios': (51.5524651, -0.5321619024569935),
#  'Planet Earth': (23.07993025, 72.49364953895747),
#  'Pleasanton, Texas': (28.967194, -98.4786269),
#  'Poland': (52.215933, 19.134422),
#  'Porkkala, Etelä-Suomen Lääni, Finland': (59.9854016, 24.43447),
#  'Porto, Portugal': (41.1494512, -8.6107884),
#  'Potty Mouth Society': (-34.6179405, 139.0045953),
#  'Prosper, Texas': (33.2385763, -96.7866058),
#  'Puberty: The Wonder Years': (54.017087700000005, -1.0872667687190645),
#  'Pure Joy': (15.3249921, 120.65489561179187),
#  'Rabat, Morocco': (34.02236, -6.8340222),
#  'Raw Love Tulum': (20.1522751, -87.4577866),
#  'Reykjanes': (63.9415014, -22.255951005219988),
#  'Reykjanes Peninsula': (63.9832697, -22.5561494),
#  'Reykjavík, Iceland': (64.145981, -21.9422367),
#  'Rio de Janeiro, Brasil': (-22.9110137, -43.2093727),
#  'Riyadh, Saudi Arabia': (24.638916, 46.7160104),
#  'Rome, Italy': (41.8933203, 12.4829321),
#  'Ronquières Festival': (0.0, 0.0),
#  'Rosario, Santa Fe': (-32.9593609, -60.6617024),
#  'SIGNAL IDUNA PARK': (51.4907602, 7.457874),
#  'SXSW': (-7.5699038000000005, 110.83544984097063),
#  'Saint Simons Island, Georgia': (31.1505097, -81.3695404),
#  'Salle Pleyel': (48.8770119, 2.3010998),
#  'Salton Sea': (33.315827, -115.7845877928179),
#  'San Antonio, Texas': (29.4246002, -98.4951405),
#  'Santa Rosa, California': (38.4404925, -122.7141049),
#  'Santo Domingo, Dominican Republic': (18.4801972, -69.942111),
#  'Sapelo Island, Georgia': (31.397448, -81.2787063),
#  'Scotland': (56.7861112, -4.1140518),
#  'Scottish Highlands': (56.8, -5.0),
#  'Scranton, Pennsylvania': (41.4086874, -75.6621294),
#  'SeaWorld Orlando': (28.4057959, -81.4767500797561),
#  'SeaWorld San Diego': (32.7650359, -117.23065947566144),
#  'Shanghai': (31.2312707, 121.4700152),
#  'Shanghai Disney Resort': (31.1433612, 121.66198394675004),
#  'Shanghai Disneyland Park': (48.872270650000004, 2.775775342115191),
#  'Shanghai Qibao Ancient Town': (31.1561762, 121.35330578026529),
#  'Shanghai, China': (31.2312707, 121.4700152),
#  'Sheikh Zayed Grand Mosque, Abu Dhabi': (24.412538849999997,
#   54.47419488446249),
#  'Sicily, Italy': (37.587794, 14.155048),
#  'Silverstone': (52.071811600000004, -1.0142991241568577),
#  'Sinaloa, Mexico': (25.0000001, -107.5000001),
#  'Singapore': (1.357107, 103.8194992),
#  'Skógafoss Water Fall': (35.7219294, -92.9493),
#  'Soho Theatre': (51.513054499999996, -0.1298638226263935),
#  'Soho, Manhattan': (40.72288, -73.9987505),
#  'Some Beach Somewhere': (29.2138338, -81.1216019),
#  'Spa Francorchamps Circuit': (50.4367166, 5.970040310059851),
#  'Spain': (39.3260685, -4.8379791),
#  "St Mary's Hospital, Manchester": (53.4611183, -2.2245162122368205),
#  'St. Louis, Missouri': (38.6280278, -90.1910154),
#  'Stamford Bridge': (51.481686499999995, -0.19103517666346065),
#  'Staplehurst, Nebraska': (40.97501, -97.172538),
#  'Sweet Oranges': (28.50071775, -81.36691196345495),
#  'Switzerland': (38.8249258, -85.0373975),
#  'Sydney Harbour Bridge': (-33.852116499999994, 151.21078120759267),
#  'TIAA Stadium': (24.24505145, 55.71705689554435),
#  'Taiwan': (23.9739374, 120.9820179),
#  'Talking Stick Resort Amphitheatre': (0.0, 0.0),
#  'Tampa Bay': (27.6886419, -82.5723193),
#  'Tate Modern': (51.5074293, -0.09934164882888792),
#  'Texas Frightmare Weekend': (32.7802132, -96.798229),
#  'The Bazaar by José Andrés': (0.0, 0.0),
#  'The Bubble': (43.6301274, -79.4344979),
#  'The CJ CUP Byron Nelson': (0.0, 0.0),
#  'The Forum (Inglewood, California)': (33.9574563, -118.3437206),
#  'The Great New York State Fair': (43.0750616, -76.2234104242945),
#  'The Ho Ho Ho House': (38.88897715, -77.0090433),
#  'The Jungle': (27.7886375, -82.7523234),
#  'The Metropolitan Museum of Art, New York': (40.643466, -73.781218),
#  'The Moon': (38.4459759, -111.1914209),
#  'The Ocean': (51.7441101, -2.294726602549609),
#  'The Oppenheim Group': (0.0, 0.0),
#  'The Queen of The Closet': (0.0, 0.0),
#  'The Ritz-Carlton, Bachelor Gulch': (0.0, 0.0),
#  'The SEMA Show': (17.1285571, -89.047875),
#  'The Tonight Show Starring Jimmy Fallon': (0.0, 0.0),
#  'The Trump White House Archived': (0.0, 0.0),
#  'The University of Texas at Austin': (31.77570475, -106.50628747547725),
#  'The Virgil': (41.9516939, -88.5245264),
#  'The White House': (32.8813903, -84.68762643616218),
#  'The YES House': (38.88897715, -77.0090433),
#  'Théâtre du Châtelet': (48.8577942, 2.3462634681786985),
#  'To the moon and back': (20.9150101, -156.3800601),
#  'Tokyo,Japan': (35.6840574, 139.7744912),
#  'Toronto, Ontario': (43.6534817, -79.3839347),
#  'Tottenham Hotspur': (51.60420725, -0.06623035000000035),
#  'Tour Eiffel': (48.8568658, 2.2898149),
#  'Turks and Caicos Islands': (21.721746, -71.5527809),
#  'U.S. Capitol Visitor Center': (38.88980425, -77.00745747160411),
#  'UT Austin Tower': (30.28627315, -97.7393655113944),
#  'United Nations': (40.750214150000005, -73.96727182919946),
#  'United Nations Headquarters': (14.5831391, 120.9865258),
#  'United States': (39.7837304, -100.445882),
#  'United States of America': (39.7837304, -100.445882),
#  'Universal CityWalk Hollywood': (34.1363097, -118.3548325),
#  'Universal Studios Hollywood': (34.089259600000005, -118.34746064552397),
#  'Universo Infinito': (20.5524118, -100.3806592),
#  'Vaught–Hemingway Stadium': (34.36198175, -89.53415232515685),
#  'Venice Film Festival': (46.1696272, 8.7954943),
#  'Venice, Italy': (45.4371908, 12.3345898),
#  'Vicarage Road Stadium': (51.64975895, -0.40134888568086824),
#  "Vice President's Mansion - Washington, D.C.": (33.208786700000005,
#   -87.5464816338646),
#  'Villa Park, England': (52.5091264, -1.8850354312212985),
#  'Virginia': (37.1232245, -78.4927721),
#  'Washington D.C.': (38.8950368, -77.0365427),
#  'Watergate Bay Hotel': (50.444927050000004, -5.041057203966153),
#  'Wembley Stadium': (51.55606945, -0.27960339379401444),
#  'Wembley Stadium connected by EE': (0.0, 0.0),
#  'West Hollywood, California': (34.0923014, -118.3692894),
#  'Whistling Straits Golf Course': (-25.8779905, 28.0542192),
#  'Who Knows': (26.6588743, 88.16073234284741),
#  'Williamsburgh Savings Bank': (41.97424545, -91.67210861453859),
#  'Willkommen': (48.5724824, 14.967983346308984),
#  'Wimbledon': (51.4214787, -0.2064027),
#  'Winter Wonderland': (29.342154100000002, 48.043984323355645),
#  'Wolf Mountain Sanctuary': (44.148092, -73.8330905),
#  'YES House': (55.8954313, -2.7316191530353366),
#  'Yas Marina Circuit': (24.4718447, 54.60578853876389),
#  'YouTube videos status subscribe my YouTube channel': (0.0, 0.0),
#  'nan': (0.0, 0.0),
#  'ВДНХ': (55.8211135, 37.6414259),
#  'Каток Вднх': (0.0, 0.0),
#  'ปั๊มเอสโซ่ บ้านพอน ถลาง,ภูเก็ต': (0.0, 0.0),
#  'ユニバーサル・スタジオ・ジャパン / Universal Studios Japan (USJ)': (0.0, 0.0)}

# %% [markdown]
# # Date of Post encoding

# %%
def date_encoding(full_date):
  date, hour = full_date.split(' ')
  d = pd.Timestamp(date) # Monday=0 ...

  dict_hour = {0.0: [6, 7, 8, 9, 10, 11, 12],     # Morning   -->  6 am to 12 pm
               1.0: [13, 14, 15, 16, 17],         # Afternoon --> 13 pm to  5 pm
               2.0: [18, 19, 20, 21],             # Evening   -->  6 pm to  9 pm
               3.0: [22, 23, 0, 1, 2, 3, 4, 5] }  # Night     -->  9 pm to  5 am

  whole_hour = int(hour.split(':')[0])
  minutes = int(hour.split(':')[1])
  seconds = int(hour.split(':')[2])

  if (seconds > 30) : minutes += 1
  if (minutes > 30) : whole_hour += 1
  if (whole_hour == 24) : whole_hour = 0

  for key in dict_hour.keys():
    if whole_hour in dict_hour[key] : return float(d.dayofweek), key

# %%
date_encoding(list(df_concat[df_concat['username'] == 'hoo.be']['date_utc'])[0])
# Out:
# (0.0, 1.0)

# %% [markdown]
# # Image type encoding

# %%
def image_type_encoding(img_type):
  return float(list(np.unique(df_concat['img_type'])).index(img_type))

# %%
for elem in list(np.unique(df_concat['img_type'])):
  print(f'{elem} --> {image_type_encoding(elem)}')
# Out:
# GraphImage --> 0.0
# GraphSidecar --> 1.0

# %% [markdown]
# # Image Loader

# %%
import torch
from torchvision.io import read_image, ImageReadMode
import torchvision
from torchvision.models import vgg16, VGG16_Weights

model_VGG = vgg16(pretrained=True)
model_VGG.eval()
weights = VGG16_Weights.DEFAULT

# %%
def image_generator(img_path, test_flag=0):
  img_org = cv2.imread(img_path, cv2.IMREAD_UNCHANGED) # original image
  if img_org is None:
    return np.zeros(1000).tolist()

  img_resized = resized = cv2.resize(img_org, (224,224), interpolation = cv2.INTER_AREA) # resize image to 224*224 to be used from VGG-16

  # filename = f"resizedImage-{img_path.strip('.jpg').split('/')[-1]}.jpg"
  filename = "resizedImage.jpg" if test_flag == 0 else "savedImage.jpg"
  cv2.imwrite(filename, img_resized)

  img = read_image(filename,ImageReadMode.RGB)

  preprocess = weights.transforms()
  batch = preprocess(img).unsqueeze(0)
  prediction = model_VGG(batch).squeeze(0).softmax(0)

  if test_flag == 0 : os.remove(filename)

  return prediction.tolist()

# %%
img_path = '/content/drive/MyDrive/Datasets/Images/_katiegeorge__2018-08-17_21__38__43.jpg'

img = cv2.imread(img_path, cv2.IMREAD_UNCHANGED)
print(f'Original Size: {img.shape}')
cv2_imshow(img)

tensor_image = image_generator(img_path,1)
##print(f'\nTesnor Image Size: {tensor_image.size()}\n')

#img_new = cv2.imread('savedImage.jpg', cv2.IMREAD_UNCHANGED)
#print(f'Reshaped Size: {img_new.shape}')
#cv2_imshow(img_new)
print(len(tensor_image))
# Out:
# Original Size: (1350, 1080, 3)
# <PIL.Image.Image image mode=RGB size=1080x1350>
# 1000

# %% [markdown]
# # Create dataset

# %%
# Define the column headers for the DataFrame
headers = ['Username', 'Followers', 'Followees', 'Verification', 'Business', 'Business Category', 'Posts', 'Caption Token 1', 'Caption Token 2', 'Caption Token 3',
           'Caption Token 4', 'Caption Token 5', 'Caption Token 6', 'Caption Token 7', 'Caption Token 8', 'Caption Token 9', 'Caption Token 10', 'Caption Token 11', 'Caption Token 12',
           'Caption Token 13', 'Caption Token 14', 'Caption Token 15', 'Caption Token 16', 'Caption Token 17', 'Caption Token 18', 'Caption Token 19', 'Caption Token 20', 'Caption Token 21',
           'Caption Token 22', 'Caption Token 23', 'Caption Token 24', 'Caption Token 25', 'Caption Token 26', 'Caption Token 27', 'Caption Token 28', 'Caption Token 29', 'Caption Token 30',
           'Caption Token 31', 'Caption Token 32', 'Caption Token 33', 'Caption Token 34', 'Caption Token 35', 'Caption Token 36', 'Caption Token 37', 'Caption Token 38', 'Caption Token 39',
           'Caption Token 40', 'Caption Token 41', 'Caption Token 42', 'Caption Token 43', 'Caption Token 44', 'Caption Token 45', 'Caption Token 46', 'Caption Token 47', 'Caption Token 48',
           'Caption Token 49', 'Caption Token 50', 'Emojis Count', 'Hashtags', 'Latitude', 'Longitude', 'Date', 'Time', 'Image Type', 'Likes', 'Comments']


# Create an empty DataFrame with these headers
df_dataset = pd.DataFrame(columns=headers)

# Define Tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("EleutherAI/gpt-neo-2.7B")
tokenizer.pad_token = tokenizer.eos_token


for i in tqdm(range(len(df_concat))):
  dir_tmp = {}
  #print(i)
  # Tensor Image
  img_path = os.path.join(images_dir, df_concat.loc[i]['username'] + '_' + str(df_concat.loc[i]['date_utc']).replace(" ", "_").replace(":","__")) + '.jpg'
  vgg_img =  image_generator(img_path)
  for i in range(len(vgg_img)):
    dir_tmp[str(i)] = vgg_img[i]

  # Username
  usrn = df_concat.loc[i]['username']
  dir_tmp["Username"] = usernanme_encoding(usrn)

  # Followers
  followers = df_concat.loc[i]['followers']
  dir_tmp["Followers"] = float(followers)

  # Followees
  followees = df_concat.loc[i]['followees']
  dir_tmp["Followees"] = float(followees)

  # Verification
  is_verified = df_concat.loc[i]['is_verified']
  dir_tmp["Verification"] = float(is_verified)

  # Business
  is_business = df_concat.loc[i]['is_business']
  dir_tmp["Business"] = float(is_business)

  # Business Category
  bus_label = df_concat.loc[i]['business_category']
  dir_tmp["Business Category"] = business_category_encoding(bus_label)

  # Posts
  num_posts = df_concat.loc[i]['number_of_posts']
  dir_tmp["Posts"] = float(num_posts)

  # Caption Token & Emojis Count
  caption = df_concat.loc[i]['caption']
  cap_tokens, emoj_count = caption_encoding(tokenizer, caption)
  for j, tok in enumerate(cap_tokens, 1):
    dir_tmp[f"Caption Token {j}"] = float(tok)
  dir_tmp["Emojis Count"] = float(emoj_count)

  # Hashtags
  has_list = df_concat.loc[i]['hashtags']
  dir_tmp["Hashtags"] = hastags_count(has_list)

  # Latitude & Longitude
  loc = df_concat.loc[i]['location']
  lat, lon = get_coordinates(loc)
  # lat, lon = dict_addresses[loc]
  dir_tmp["Latitude"] = lat
  dir_tmp["Longitude"] = lon

  # Date and Time
  full_date = df_concat.loc[i]['date_utc']
  date, time = date_encoding(full_date)
  dir_tmp["Date"] = date
  dir_tmp["Time"] = time

  # Image Type
  img_type = df_concat.loc[i]['img_type']
  dir_tmp["Image Type"] = image_type_encoding(img_type)

  ####################################################################

  # Likes
  likes = df_concat.loc[i]['likes']
  dir_tmp["Likes"] = float(likes)

  # Comments
  comments = df_concat.loc[i]['comments']
  dir_tmp["Comments"] = float(comments)

  # Add the row to the DataFrame
  df_dataset = df_dataset.append(dir_tmp, ignore_index=True)
# Out:
# 100%|██████████| 2671/2671 [40:57<00:00,  1.09it/s]

# %%
df_dataset
# Out:
#       Username  Followers  Followees  Verification  Business  \
# 0         94.0    22566.0       71.0           1.0       1.0
# 1         94.0    22566.0       71.0           1.0       1.0
# 2         94.0    22566.0       71.0           1.0       1.0
# 3         94.0    22566.0       71.0           1.0       1.0
# 4         94.0    22566.0       71.0           1.0       1.0
# ...        ...        ...        ...           ...       ...
# 2666      94.0    22566.0       71.0           1.0       1.0
# 2667      94.0    22566.0       71.0           1.0       1.0
# 2668      94.0    22566.0       71.0           1.0       1.0
# 2669      94.0    22566.0       71.0           1.0       1.0
# 2670      94.0    22566.0       71.0           1.0       1.0
#
#       Business Category  Posts  Caption Token 1  Caption Token 2  \
# 0                   1.0  348.0            464.0            717.0
# 1                   1.0  348.0            464.0            717.0
# 2                   1.0  348.0            464.0            717.0
# 3                   1.0  348.0            464.0            717.0
# 4                   1.0  348.0            464.0            717.0
# ...                 ...    ...              ...              ...
# 2666                1.0  348.0            464.0            717.0
# 2667                1.0  348.0            464.0            717.0
# 2668                1.0  348.0            464.0            717.0
# 2669                1.0  348.0            464.0            717.0
# 2670                1.0  348.0            464.0            717.0
#
#       Caption Token 3  ...           990           991           992  \
# 0              1683.0  ...  0.000000e+00  0.000000e+00  0.000000e+00
# 1              1683.0  ...  0.000000e+00  0.000000e+00  0.000000e+00
# 2              1683.0  ...  0.000000e+00  0.000000e+00  0.000000e+00
# 3              1683.0  ...  0.000000e+00  0.000000e+00  0.000000e+00
# 4              1683.0  ...  0.000000e+00  0.000000e+00  0.000000e+00
# ...               ...  ...           ...           ...           ...
# 2666           1683.0  ...  1.540743e-08  5.848895e-08  5.764909e-08
# 2667           1683.0  ...  2.215644e-08  2.976236e-08  4.801437e-09
# 2668           1683.0  ...  7.198442e-08  6.232727e-08  9.155664e-08
# 2669           1683.0  ...  1.244301e-07  4.659513e-08  6.310743e-07
# 2670           1683.0  ...  9.937279e-07  1.239373e-06  1.032549e-06
#
#                993           994           995           996           997  \
# 0     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 1     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 2     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 3     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 4     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ...            ...           ...           ...           ...           ...
# 2666  8.989597e-08  2.967782e-07  1.279557e-07  2.918121e-07  7.234205e-09
# 2667  4.831751e-08  5.136811e-07  3.722031e-08  1.971586e-08  1.011932e-08
# 2668  3.690384e-07  4.337970e-06  6.601301e-07  2.282336e-06  3.176082e-08
# 2669  1.079178e-07  7.582918e-06  3.400634e-06  1.740985e-06  3.382646e-07
# 2670  5.026470e-06  3.651924e-06  1.269329e-05  2.504780e-06  1.021403e-06
#
#                998           999
# 0     0.000000e+00  0.000000e+00
# 1     0.000000e+00  0.000000e+00
# 2     0.000000e+00  0.000000e+00
# 3     0.000000e+00  0.000000e+00
# 4     0.000000e+00  0.000000e+00
# ...            ...           ...
# 2666  1.324046e-06  1.510216e-03
# 2667  2.002270e-07  2.401269e-07
# 2668  1.150381e-06  2.318747e-05
# 2669  2.276448e-03  2.955427e-06
# 2670  3.168434e-05  2.295704e-05
#
# [2671 rows x 1066 columns]

# %%
df_dataset.to_csv(f'Dataset_Complete_new.csv')

# %% [markdown]
# # Visualisation - Grpahs

# %%
# for file in os.listdir(images_dir):
#     old_file = os.path.join(images_dir, file)
#     new_file = os.path.join(images_dir, file.replace(" ","_"))
#     os.rename(old_file, new_file)

# %%
# hastag_list = ['nan']
# tot_len = 0
# for has_list in list(np.unique(df_concat['hashtags'])):
#   has_list = [j.strip('[], ') for j in has_list.split(',')]
#   tot_len += len(has_list)
#   # for has in has_list:
#   #   print(has)
#   #   if has not in hastag_list: hastag_list.append(has)

# tot_len
